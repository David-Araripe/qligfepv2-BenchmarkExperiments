# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path
from QligFEP.pdb_utils import (
    nest_pdb,
    unnest_pdb,
    read_pdb_to_dataframe,
    write_dataframe_to_pdb,
)
from QligFEP.CLI.pdb_to_amber import asp_search, histidine_search
import pandas as pd

# %% [markdown]
# # Define functions

# %%
# Need to remove Hs from GLY
# Need to cap the last residue

rename_mapping = {
    "ACE": {
        "3H": "HH33",
        "2H": "HH32",
        "1H": "HH31",
        "H2_3": "HH33",
        "H2_2": "HH32",
        "H2_1": "HH31",
        "3HH3": "HH33",
        "2HH3": "HH32",
        "1HH3": "HH31",
        "C1": "C",
        "C2": "CH3",
        "O1": "O",
    },
    "NMA": {
        "C": "CT",
        "H3": "HA3",
        "H2": "HA2",
        "H1": "HA1",
        "3HA": "HA3",
        "2HA": "HA2",
        "1HA": "HA1",
        "H1_3": "HA3",
        "H1_2": "HA2",
        "H1_1": "HA1",
        "C1": "CA",
        "N1": "N",
    },
    "GLY": {"H1": "H", "H2": "H"},
    "ARG": {"H2": "H"},
    "GLU": {"H2": "H"},
    "GLN": {"H2": "H"},
    "THR": {"H2": "H"},
    "LEU": {"H1": "H"},
    "VAL": {
        "3HG1": "HG13",
        "2HG1": "HG12",
        "1HG1": "HG11",
        "3HG2": "HG13",
        "2HG2": "HG12",
        "1HG2": "HG11",
    },
}


def reindex_pdb_residues(pdb_path: Path, out_pdb_path: str):
    pdb_df = read_pdb_to_dataframe(pdb_path)
    uniq_indexes = pdb_df.set_index(
        ["residue_seq_number", "residue_name", "chain_id", "insertion_code"]
    ).index
    resn_mapping = {resn: idx for idx, resn in enumerate(uniq_indexes.unique(), 1)}
    pdb_df["residue_seq_number"] = uniq_indexes.map(resn_mapping)
    pdb_df["insertion_code"] = ""
    # pdb_df = pdb_df.assign(residue_seq_number=uniq_indexes.map(resn_mapping))
    write_dataframe_to_pdb(pdb_df, out_pdb_path)


def correct_amino_acid_atom_names(npdb_i, resname, rename_mapping):
    """corrects the amino acid atom names according to the mapping provided

    Args:
        npdb_i: nested pdb data structure for a single residue
        resname: the residue name
        rename_mapping: a dictionary mapping old names to new names
    """
    if resname in rename_mapping:
        for old_name, new_name in rename_mapping[resname].items():
            npdb_i = [extract_and_replace(x, old_name, new_name) for x in npdb_i]
            # certify that we have the alignment as expected for pdb files
    return npdb_i


def extract_and_replace(line, old_name, new_name):
    """extracts the atom name and replaces it with the new name"""
    atom_name = line[12:16].strip()
    if atom_name != old_name:
        return line
    new_atom_name = atom_name.replace(old_name, new_name).strip()
    if len(new_atom_name) == 4:
        return line[:12] + new_atom_name + line[16:]
    else:
        # return left aligned atom name always with len() == 3 but with a " " in the beginning
        return line[:12] + f" {new_atom_name:<3}" + line[16:]


def fix_pdb(pdb_path: Path, rename_mapping):
    renamed_pdb_path = pdb_path.with_name(pdb_path.stem + "_renamed.pdb")
    with open(pdb_path) as f:
        pdb_lines = f.readlines()

    npdb = nest_pdb(pdb_lines)
    npdb = asp_search(npdb)
    npdb = histidine_search(npdb)

    for i, res in enumerate(npdb):
        resname = res[-1][17:20]
        if resname == "HIS":  # rename to HIP according to our FF library
            npdb[i] = [x.replace("HIS", "HIP") for x in npdb[i]]
            resname = "HIP"
        if resname == "NME":  # we use NMA in our FF library
            npdb[i] = [x.replace("NME", "NMA") for x in npdb[i]]
            resname = "NMA"
        npdb[i] = correct_amino_acid_atom_names(npdb[i], resname, rename_mapping)
    pdb_lines = unnest_pdb(npdb)

    with open(renamed_pdb_path, "w") as f:
        for line in pdb_lines:
            f.write(line)
    return pdb_lines


def cap_and_reindex_pdb(inp_pdb: Path):
    """Function that removes additionaly hydrogens from N terminal not covered
    in our library files, caps the last residue and reindexes the atoms

    Args:
        inp_pdb: path for the pdb file
    """

    pdb_df = read_pdb_to_dataframe(inp_pdb)

    # remove extra Hs from the first Gly residue
    if pdb_df["residue_name"].values[0] in ["GLY", "LEU", "GLU", "ASH", "ILE", "ASN"]:
        first_residue = pdb_df["residue_seq_number"].values[0]
        # remove atoms with atom_name H2 and H3, and rename H1 to H
        subset_first = pdb_df[
            (pdb_df["residue_seq_number"] == first_residue)
            & (~pdb_df["atom_name"].isin(["H2", "H3"]))
        ].copy()
        subset_first["atom_name"] = subset_first["atom_name"].str.replace("H1", "H")
        rm_idxs = pdb_df.query("residue_seq_number == @first_residue").index
        pdb_df = pd.concat(
            [subset_first, pdb_df.drop(index=rm_idxs)], ignore_index=True
        )
    # cap the last residue
    last_residue = pdb_df["residue_name"].values[-1]
    last_residue_number = pdb_df["residue_seq_number"].values[-1]  # noqa: F841
    if last_residue in ["ILE", "NME"]:
        rm_idxs = pdb_df.query("residue_seq_number == @last_residue_number").index
        pdb_df.drop(index=rm_idxs, inplace=True)
    _len = len(pdb_df)
    pdb_df["atom_serial_number"] = range(1, _len + 1)
    write_dataframe_to_pdb(pdb_df, inp_pdb)

# %% [markdown]
# # Rename the protein files

# %%
pdb_paths = sorted(Path().glob("*/protein/protein.pdb"))

# %%
pdb_path = Path("thrombin/protein/protein.pdb")

reindexed_path = pdb_path.with_stem(pdb_path.stem + "_reindexed")
reindex_pdb_residues(pdb_path, out_pdb_path=reindexed_path)

# %%
for pdb_path in pdb_paths:
    reindexed_path = pdb_path.with_stem(pdb_path.stem + "_reindexed")
    reindex_pdb_residues(pdb_path, out_pdb_path=reindexed_path)
    fix_pdb(reindexed_path, rename_mapping)
    # cap_and_reindex_pdb(pdb_path.with_stem(pdb_path.stem + "_renamed"))

# %% [markdown]
# # Rename the water & cofactor files

# %%
atom_renaming_dict = {
    # salts
    "MG": "MAG",
    "ZN": "ZIN",
    "NA": "SOD",
}
residue_renaming_dict = {
    "MG": "MAG",
    "ZN": "ZIN",
}


def rename_cofactor_atoms(pdb_path: Path, atom_renaming_dict: dict):
    pdb_df = read_pdb_to_dataframe(pdb_path).assign(
        atom_name=lambda x: x["atom_name"].replace(atom_renaming_dict),
        residue_name=lambda x: x["residue_name"]
        .str.strip(" ")
        .replace(residue_renaming_dict),
    )
    write_dataframe_to_pdb(pdb_df, pdb_path)

# %%
pdb_paths = sorted(Path().glob("*/protein/protein_reindexed_renamed.pdb"))

for pdb_path in pdb_paths:
    if pdb_path.stat().st_size != 0:
        rename_cofactor_atoms(pdb_path, atom_renaming_dict)

# %% [markdown]
# # Merge renamed protein & cofactor files

# %%
# prot_root_paths = sorted(Path().glob("*/protein/"))

# for _path in prot_root_paths:
#     processed_pdbs = []
#     protfile = _path / "protein_renamed.pdb"
#     cofactor = _path / "cofactors_crystalwater_renamed.pdb"

#     prot_df = read_pdb_to_dataframe(protfile)

#     # reindex both atom_serial_number and residue_seq_number
#     prot_df["atom_serial_number"] = range(1, len(prot_df) + 1)
#     residue_seq_mapping = {
#         old: new
#         for old, new in zip(
#             prot_df["residue_seq_number"].unique(),
#             range(1, len(prot_df["residue_seq_number"].unique()) + 1),
#         )
#     }
#     prot_df["residue_seq_number"] = prot_df["residue_seq_number"].replace(
#         residue_seq_mapping
#     )
#     last_prot_res = prot_df["residue_seq_number"].max()
#     last_prot_atom = prot_df["atom_serial_number"].max()
#     processed_pdbs.append(prot_df)

#     if cofactor.exists():
#         print("Including cofactors for ", _path)
#         cof_df = read_pdb_to_dataframe(cofactor)
#         cof_df["atom_serial_number"] = range(
#             last_prot_res + 1, last_prot_res + len(cof_df) + 1
#         )
#         residue_seq_mapping = {
#             old: new
#             for old, new in zip(
#                 cof_df["residue_seq_number"].unique(),
#                 range(
#                     last_prot_res + 1,
#                     last_prot_res + len(cof_df["residue_seq_number"].unique() + 1),
#                 ),
#             )
#         }
#         cof_df["residue_seq_number"] = cof_df["residue_seq_number"].replace(
#             residue_seq_mapping
#         )
#         processed_pdbs.append(cof_df)
#     final_df = pd.concat(processed_pdbs, ignore_index=True)
#     write_dataframe_to_pdb(final_df, protfile.parent / "protfile_final.pdb")

# %% [markdown]
# # Preparing data

# %% [markdown]
# running qprep through the notebook. First we get the Center of Geometry (COG) of all the ligands, and then use it prepare the water spheres of the respective systems. The COG is the center of the water sphere

# %%
import shutil
from QligFEP.CLI.qprep_cli import main, QprepError, QprepAtomLibMissingError
from QligFEP.CLI.cog_cli import MolecularCOG
import argparse
import os

prot_root_paths = sorted([p.absolute() for p in Path().glob("*/protein/")])
cwd = Path.cwd()

for _path in prot_root_paths:
    print("Processing: ", _path.parent.name)
    if _path.parent.name == "pfkfb3":
        print(f"{_path.parent.name} not in the repo yet as of 20241010")
        continue
    processed_pdbs = []
    protfile = _path / "protein_reindexed_renamed.pdb"
    qprep_dir = _path / "qprep"
    if not qprep_dir.exists():
        qprep_dir.mkdir()
    shutil.copy(protfile, qprep_dir / "protein.pdb")

    # change the working directory to the qprep directory
    os.chdir(qprep_dir)

    # calculate the center of geometry for the ligands
    ligpath = _path.parent / "ligands/ligands.sdf"
    cog = MolecularCOG(ligpath)
    coords_str = cog()
    coordinates = [n for n in coords_str.strip("[]").split()]

    args = argparse.Namespace()
    args.log_level = "info"
    args.input_pdb_file = "protein.pdb"
    args.FF = "AMBER14sb"
    args.cog = coordinates
    args.sphereradius = 25
    args.cysbond = "auto"
    args.solvent_pack = 3.0

    try:
        main(args)
    except QprepError as e:
        print("Qprep Error: ", e)
        pass
        # continue
    except QprepAtomLibMissingError as e:
        print("Qprep atomlib missing:", e)
        continue

os.chdir(cwd)
# Out:
# 2024-10-11 16:32:19 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# 2024-10-11 16:32:19 | WARNING  | QligFEP.CLI.utils:cysbonds_for_qprep:36 - Disulfide bonds detected on CYS residues! Renaming to CYX
# Processing:  bace
# 2024-10-11 16:32:20 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:20 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:20 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:20 | WARNING  | QligFEP.CLI.qprep_cli:main:268 - Found 1 water molecules outside the sphere radius.
# 2024-10-11 16:32:20 | WARNING  | QligFEP.CLI.qprep_cli:main:269 - Removing these water molecules from the water.pdb file.
# 2024-10-11 16:32:20 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# 2024-10-11 16:32:20 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# Processing:  cdk2
# STOP qprep ended normally
# 2024-10-11 16:32:21 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:21 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:21 | INFO     | QligFEP.CLI.qprep_cli:main:278 - All water molecules are inside the sphere radius.
# 2024-10-11 16:32:21 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Processing:  cdk8
# 2024-10-11 16:32:22 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:22 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/cdk8/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:22 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/cdk8/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:22 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Qprep Error:  {'>>>>> ERROR: Too many atoms in residue ASH    366\n>>>>> ERROR: The check of the PDB file failed.'}
# Processing:  cmet
# 2024-10-11 16:32:23 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:23 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:23 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:23 | WARNING  | QligFEP.CLI.qprep_cli:main:268 - Found 6 water molecules outside the sphere radius.
# 2024-10-11 16:32:23 | WARNING  | QligFEP.CLI.qprep_cli:main:269 - Removing these water molecules from the water.pdb file.
# 2024-10-11 16:32:23 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Processing:  eg5
# 2024-10-11 16:32:24 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:24 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:24 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:24 | WARNING  | QligFEP.CLI.qprep_cli:main:268 - Found 9 water molecules outside the sphere radius.
# 2024-10-11 16:32:24 | WARNING  | QligFEP.CLI.qprep_cli:main:269 - Removing these water molecules from the water.pdb file.
# 2024-10-11 16:32:25 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# 2024-10-11 16:32:25 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# Processing:  hif2a
# STOP qprep ended normally
# 2024-10-11 16:32:25 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:25 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:25 | INFO     | QligFEP.CLI.qprep_cli:main:278 - All water molecules are inside the sphere radius.
# 2024-10-11 16:32:25 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# 2024-10-11 16:32:25 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# Processing:  jnk1
# STOP qprep ended normally
# 2024-10-11 16:32:25 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/jnk1/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:25 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/jnk1/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:25 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/jnk1/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:25 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/jnk1/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:25 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# 2024-10-11 16:32:25 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# Qprep Error:  {'>>>>> ERROR: Too many atoms in residue HIP    358\n>>>>> ERROR: Too many atoms in residue PRO    359\n>>>>> ERROR: Too many atoms in residue PHE    368\n>>>>> ERROR: The check of the PDB file failed.'}
# Processing:  mcl1
# STOP qprep ended normally
# 2024-10-11 16:32:26 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/mcl1/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:26 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/mcl1/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:26 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Qprep Error:  {'>>>>> ERROR: Too many atoms in residue GLY      1\n>>>>> ERROR: The check of the PDB file failed.'}
# Processing:  p38
# 2024-10-11 16:32:26 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:27 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:27 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:27 | WARNING  | QligFEP.CLI.qprep_cli:main:268 - Found 8 water molecules outside the sphere radius.
# 2024-10-11 16:32:27 | WARNING  | QligFEP.CLI.qprep_cli:main:269 - Removing these water molecules from the water.pdb file.
# 2024-10-11 16:32:27 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Processing:  pfkfb3
# pfkfb3 not in the repo yet as of 20241010
# Processing:  ptp1b
# 2024-10-11 16:32:27 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:28 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:28 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:28 | WARNING  | QligFEP.CLI.qprep_cli:main:268 - Found 4 water molecules outside the sphere radius.
# 2024-10-11 16:32:28 | WARNING  | QligFEP.CLI.qprep_cli:main:269 - Removing these water molecules from the water.pdb file.
# 2024-10-11 16:32:28 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Processing:  shp2
# 2024-10-11 16:32:29 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:29 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:29 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:29 | INFO     | QligFEP.CLI.qprep_cli:main:278 - All water molecules are inside the sphere radius.
# 2024-10-11 16:32:29 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Processing:  syk
# 2024-10-11 16:32:30 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:30 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:72 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/syk/protein/qprep/qprep.out. Your protein file likely contains atoms that are not present in the forcefield's .lib & .prm files:,
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:30 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# 2024-10-11 16:32:30 | WARNING  | QligFEP.CLI.utils:cysbonds_for_qprep:36 - Disulfide bonds detected on CYS residues! Renaming to CYX
# Qprep atomlib missing: {'>>> Atom CH3  in residue no.   273 not found in library entry for NMA '}
# Processing:  thrombin
# 2024-10-11 16:32:30 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:30 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/thrombin/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:30 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/thrombin/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:30 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/thrombin/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:30 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/thrombin/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:30 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# Qprep Error:  {'>>>>> ERROR: Too many atoms in residue ILE     31\n>>>>> ERROR: Too many atoms in residue GLY    290\n>>>>> ERROR: Residue number   324 is of unknown type  NA \n>>>>> ERROR: The check of the PDB file failed.'}
# Processing:  tnks2
# 2024-10-11 16:32:31 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# STOP qprep ended normally
# 2024-10-11 16:32:31 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/tnks2/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:31 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/tnks2/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:31 | ERROR    | QligFEP.CLI.qprep_cli:qprep_error_check:65 - Errors found in qprep output file /zfsdata/data/david/qligfepv2-BenchmarkExperiments/startFiles/tnks2/protein/qprep/qprep.out. Please check if the amino acids in your pdb file match the residue & atom conventions on the forcefield .lib & .prm files:
# /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.prm & /zfsdata/data/david/Q/src/QligFEP/FF/AMBER14sb.lib
# 2024-10-11 16:32:31 | WARNING  | QligFEP.CLI.cog_cli:_cog_sdf:66 - Calculating for all ligands in the file.
# 2024-10-11 16:32:31 | WARNING  | QligFEP.CLI.qprep_cli:main:227 - qprep.inp already exists!! Overwriting...
# Qprep Error:  {'>>>>> ERROR: Too many atoms in residue GLY      1\n>>>>> ERROR: Too many atoms in residue MET    163\n>>>>> ERROR: The check of the PDB file failed.'}
# Processing:  tyk2
# STOP qprep ended normally
# 2024-10-11 16:32:31 | INFO     | QligFEP.CLI.qprep_cli:main:235 - qprep run finished. Check the output `qprep.out` for more information.
# 2024-10-11 16:32:31 | INFO     | QligFEP.CLI.qprep_cli:main:258 - water.pdb file created.
# 2024-10-11 16:32:31 | INFO     | QligFEP.CLI.qprep_cli:main:278 - All water molecules are inside the sphere radius.

# %% [markdown]
# # TODO:
# After running qprep, remove the water molecules from `protein.pdb`.

# %% [markdown]
# # Checking for qprep errors:

# %%
import subprocess

outqprep_pattern = "*/protein/qprep/qprep.out"
p = subprocess.Popen(
    " ".join(["grep", "-winr", "error", outqprep_pattern]),
    stdout=subprocess.PIPE,
    stderr=subprocess.PIPE,
    shell=True,
    text=True,
)
stdout, stderr = p.communicate()
stdout.split("\n")
# Out:
# ['']

# %% [markdown]
# # Move perturbation files to directory

# %%
from pathlib import Path
from joblib import Parallel, delayed
import shutil


def copyfile(src: Path, dest: Path):
    try:
        shutil.copy(src, dest / src.name)
    except FileNotFoundError as e:
        print(f"error for src: {src}:\n{e}")

# %%
from QligFEP.chemIO import MoleculeIO

targets = [p for p in sorted(Path().glob("*/")) if p.is_dir()]

destpath = Path.cwd().parent / "perturbations"
for target in targets:
    ligands_sdf = sorted((target / "ligands/").glob("*.sdf"))
    ligands_pdb = sorted((target / "ligands/").glob("*.pdb"))
    ligands_lib = sorted((target / "ligands/").glob("*.lib"))
    ligands_prm = sorted((target / "ligands/").glob("*.prm"))
    lomap_file = target / "ligands/mapping.json"
    protein_file = target / "protein/qprep/protein.pdb"
    noHOH_protfile = target / "protein/qprep/protein_noHOH.pdb"
    water_file = target / "protein/qprep/water.pdb"
    perturbation_root = destpath / target.name
    if not perturbation_root.exists():
        perturbation_root.mkdir(parents=True, exist_ok=True)
    allfiles = (
        ligands_pdb
        + ligands_lib
        + ligands_prm
        + [
            lomap_file,
            (noHOH_protfile if noHOH_protfile.exists() else protein_file),
            water_file,
        ]
    )
    molio = MoleculeIO(str(list(ligands_sdf)[0]))
    molio.write_to_single_sdf(
        str(perturbation_root / "ligands.sdf")
    )  # reindex hydrogens
    Parallel(n_jobs=6, backend="threading")(
        delayed(copyfile)(src, perturbation_root) for src in allfiles
    )
    if (
        perturbation_root / "protein_noHOH.pdb"
    ).exists():  # rename it to just protein.pdb
        shutil.move(
            perturbation_root / "protein_noHOH.pdb", perturbation_root / "protein.pdb"
        )
# Out:
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 20. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 1oi9. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 26. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 1oiu. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 1h1q. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 21. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 22. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 1h1r. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 17. Reindexed.
# 2024-09-10 10:49:50 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 1oiy. Reindexed.
# 2024-09-10 10:49:51 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/cdk2/ligands.sdf
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 40. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 30. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 42. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 37. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 38. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 13. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 41. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 21. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 22. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 39. Reindexed.
# 2024-09-10 10:49:51 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 43. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 32. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 26. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 20. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 28. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 35. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 18. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 19. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 44. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 33. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 25. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 16. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 29. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 17. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 15. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 36. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 27. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 24. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 14. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 34. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 45. Reindexed.
# 2024-09-10 10:49:52 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/cdk8/ligands.sdf
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3402745_200_5. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3402744_300_4. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3402754_40_14. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3402761_1_21. Reindexed.
# 2024-09-10 10:49:52 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3402749_500_9. Reindexed.
# 2024-09-10 10:49:53 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/cmet/ligands.sdf
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1084677. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1083517. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1084143. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1084678. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1078691. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1078774. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1085666. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1085895. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1093088. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1084676. Reindexed.
# 2024-09-10 10:49:53 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1089056. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1084935. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1086410. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1086409. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1077204. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1096003. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1093087. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1088740. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1089393. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1078998. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1084115. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1083836. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1077227. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1085692. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1082248. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1096002. Reindexed.
# 2024-09-10 10:49:54 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL1082249. Reindexed.
# 2024-09-10 10:49:54 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/eg5/ligands.sdf
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 231. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 163. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 289. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 57. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 15. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 227. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 234. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 167. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 254. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 206. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 336. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 155. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 338. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 252. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 290. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 67. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 165. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 256. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 215. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 156. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 235. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 1. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 35. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 25. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 61. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 42. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 251. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 54. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 41. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 43. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 84. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 31. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 30. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 124. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 50. Reindexed.
# 2024-09-10 10:49:55 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 224. Reindexed.
# 2024-09-10 10:49:56 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/hif2a/ligands.sdf
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 43. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 56. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 47. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 37. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 65. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 60. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 67. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 46. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 50. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 61. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 36. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 53. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 31. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 58. Reindexed.
# 2024-09-10 10:49:56 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 34. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 35. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 49. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 52. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 48. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 63. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 30. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 33. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 32. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 28. Reindexed.
# 2024-09-10 10:49:57 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 27. Reindexed.
# 2024-09-10 10:49:57 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/mcl1/ligands.sdf
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2r. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2s. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_3flw. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_3fmh. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_3fln. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2n. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2t. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2l. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2x. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2e. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2k. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_3fly. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2aa. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2g. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2bb. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2y. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2gg. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2ee. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2z. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2m. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2o. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2ff. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2v. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_3flz. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2p. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2f. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2h. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2i. Reindexed.
# 2024-09-10 10:49:58 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule p38a_2j. Reindexed.
# 2024-09-10 10:49:58 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/p38/ligands.sdf
# 2024-09-10 10:50:00 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/pde2/ligands.sdf
# 2024-09-10 10:50:00 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 29. Reindexed.
# 2024-09-10 10:50:00 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 55. Reindexed.
# 2024-09-10 10:50:00 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 56. Reindexed.
# 2024-09-10 10:50:00 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 57. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 26. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 37. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 35. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 24. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 52. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 33. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 34. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 69. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 70. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 19. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 38. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 58. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 64. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 65. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 41. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 59. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 42. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 31. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 63. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 20. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 62. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 48. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 43. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 39. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 47. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 49. Reindexed.
# 2024-09-10 10:50:01 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 44. Reindexed.
# 2024-09-10 10:50:01 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/pfkfb3/ligands.sdf
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 20667_2qbp. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23485. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23476. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23480. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23486. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23482. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23484. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23474. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23475. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 20670_2qbs. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23473. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23479. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23483. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23477. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23466. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23469. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23470. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23468. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23467. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23471. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 20669_2qbr. Reindexed.
# 2024-09-10 10:50:02 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 23472. Reindexed.
# 2024-09-10 10:50:03 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/ptp1b/ligands.sdf
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E8. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E3. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 6. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E4. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E1. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E9. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E14. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E2. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule SHP099-1. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E30. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E6. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule SHP836-2. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E24. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E23. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 3. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E27. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E28. Reindexed.
# 2024-09-10 10:50:03 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E29. Reindexed.
# 2024-09-10 10:50:04 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E25. Reindexed.
# 2024-09-10 10:50:04 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E22. Reindexed.
# 2024-09-10 10:50:04 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 10. Reindexed.
# 2024-09-10 10:50:04 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 7. Reindexed.
# 2024-09-10 10:50:04 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule E5. Reindexed.
# 2024-09-10 10:50:04 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule 11. Reindexed.
# 2024-09-10 10:50:04 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/shp2/ligands.sdf
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265000. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265001. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3264998. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3264995. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265002. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3264996. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3264997. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265003. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265008. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265004. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265009. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3264994. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265010. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265005. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3264999. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265034. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265011. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265033. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265006. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265024. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265012. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265026. Reindexed.
# 2024-09-10 10:50:05 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265036. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265023. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265016. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265028. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265018. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265037. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265032. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265027. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265017. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265025. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265020. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3259820. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265019. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265022. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265021. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265013. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265015. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265031. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265014. Reindexed.
# 2024-09-10 10:50:06 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule CHEMBL3265029. Reindexed.
# 2024-09-10 10:50:06 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/syk/ligands.sdf
# 2024-09-10 10:50:08 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/thrombin/ligands.sdf
# 2024-09-10 10:50:09 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/tnks2/ligands.sdf
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_54. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule jmc_23. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_47. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule jmc_27. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_46. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_31. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_42. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_50. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_45. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule jmc_28. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_55. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_43. Reindexed.
# 2024-09-10 10:50:09 | WARNING  | QligFEP.chemIO:_force_H_reindexing:51 - Hydrogens not at the end of the atom list for molecule ejm_48. Reindexed.
# 2024-09-10 10:50:09 | INFO     | QligFEP.chemIO:write_to_single_sdf:164 - `self.molecules` written to /zfsdata/data/david/qligfepv2-BenchmarkExperiments/perturbations/tyk2/ligands.sdf
