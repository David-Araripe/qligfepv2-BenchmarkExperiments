# %% [markdown]
# # Rebuilding the benchmark input structures
#
# This notebook rebuilds the 25 Å protein and water-sphere inputs reproducibly. It:
#
# 1. normalizes protein atom names with the shared QligFEP implementation;
# 2. preserves the legacy all-atom ligand centers used by the original benchmark;
# 3. neutralizes charged residues according to Q's charge-group boundary rule, including direct cross-boundary salt-bridge partners; and
# 4. runs `qprep` once to generate and validate the final topology, protein, and water sphere.
#
# Ligand and cofactor parameterization is intentionally not run here because AM1-BCC is slow. Existing parameter files are reused; `perturbations/Makefile` and `qparams` provide the separate regeneration workflow. For PFKFB3, qprep consumes the committed combined protein/cofactor force field, whose cofactors were parameterized with OpenFF Sage 2.2.1 and AM1-BCC.
#
# For AMBER14sb protein residues, qprep creates one charge group containing the complete residue and tests its unweighted centroid against the nominal exclusion radius. QligFEP applies that same rule before launching qprep. The effective solvent radius reported afterward controls water behavior; it is recorded for provenance but is not used for protein neutralization.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import argparse
import json
import os
import re
import shutil
from contextlib import contextmanager
from pathlib import Path

import numpy as np
from QligFEP.CLI.pdb_to_amber import fix_pdb, reindex_pdb_residues
from QligFEP.CLI.qprep_cli import main as run_qprep_prot
from QligFEP.pdb_utils import read_pdb_to_dataframe, write_dataframe_to_pdb

STARTFILES = Path.cwd()
PERTURBATIONS = STARTFILES.parent / "perturbations"
SPHERE_RADIUS = 25.0
SALT_BRIDGE_CUTOFF = 4.0
QPREP_DIRNAME = "qprep"

# These are the all-atom ligand COGs used to build the committed benchmark. Do not
# recalculate them with MolecularCOG -- current version does not take hydrogens into account.
# While this is the correct way to calculate COGs, we leave it as is to avoid changing the benchmark.
LEGACY_COG = {
    "bace": "14.930 -1.426 -0.943",
    "cdk2": "0.897 26.524 8.756",
    "cdk8": "-4.591 12.018 -9.456",
    "cmet": "21.448 30.911 54.222",
    "eg5": "13.427 -4.848 2.961",
    "hif2a": "24.057 -0.279 -10.420",
    "jnk1": "22.449 7.199 31.302",
    "mcl1": "-2.207 -47.416 6.615",
    "p38": "22.637 10.252 31.178",
    "pfkfb3": "91.897 49.193 267.566",
    "ptp1b": "41.430 12.734 15.360",
    "shp2": "23.403 41.339 4.211",
    "syk": "0.192 0.704 13.540",
    "thrombin": "17.072 -12.649 22.515",
    "tnks2": "-14.994 -19.425 -26.211",
    "tyk2": "-4.689 26.119 -30.570",
}
TARGETS = tuple(LEGACY_COG)

# These chains are absent from the benchmark monomer inputs.
EXCLUDED_CHAINS = {"cdk2": {"B"}, "cdk8": {"B"}}


@contextmanager
def working_directory(path):
    previous = Path.cwd()
    os.chdir(path)
    try:
        yield
    finally:
        os.chdir(previous)


for target in TARGETS:
    if not (STARTFILES / target).is_dir():
        raise FileNotFoundError(f"Missing target directory: {target}")

# %% [markdown]
# ## 1. Normalize proteins
#
# `fix_pdb` is the single source of truth for AMBER atom naming. Geometry-sensitive acidic residues and neutral arginines are normalized without moving their intended protons, and malformed or duplicate atom identities fail before qprep.
#
# Historical manual corrections that are already present in the source structures are documented in [PROT_PREPARATION.md](../PROT_PREPARATION.md). CDK2 and CDK8 chain selection is applied explicitly below; no edits to generated PDB files should be made by hand.

# %%
ION_RENAMES = {"MG": "MAG", "ZN": "ZIN", "NA": "SOD"}

for target in TARGETS:
    protein_dir = STARTFILES / target / "protein"
    source = protein_dir / "protein.pdb"
    reindexed = protein_dir / "protein_reindexed.pdb"
    normalized = protein_dir / "protein_reindexed_renamed.pdb"

    reindex_pdb_residues(source, out_pdb_path=reindexed)
    fix_pdb(reindexed, out_name=normalized)

    protein_df = read_pdb_to_dataframe(normalized)
    excluded_chains = EXCLUDED_CHAINS.get(target, set())
    if excluded_chains:
        protein_df = protein_df[~protein_df["chain_id"].isin(excluded_chains)].copy()

    protein_df["atom_name"] = protein_df["atom_name"].replace(ION_RENAMES)
    protein_df["residue_name"] = protein_df["residue_name"].str.strip().replace(ION_RENAMES)
    write_dataframe_to_pdb(protein_df, normalized)
    print(f"{target:9} -> {normalized.relative_to(STARTFILES)} ({len(protein_df)} atoms)")

# %% [markdown]
# ## 2. Neutralize and run qprep
#
# QligFEP reproduces qprep's `set_cgp()` boundary test directly. With AMBER14sb and `switch_atoms off`, standard protein residues have no explicit `[charge_groups]` entry, so Q creates one group containing every residue atom and excludes it when its unweighted centroid is at or beyond the nominal 25 Å radius.
#
# Charged excluded residues are neutralized together with direct, oppositely charged included partners within 4 Å, measured between charged heavy atoms.
#
# Outputs are written to each target's `protein/qprep/` directory. Re-running the notebook refreshes those files.

# %%
EFFECTIVE_RADIUS_RE = re.compile(r"Eff\. solvent radius\s*=\s*([0-9.]+)")


def make_qprep_args(input_name, forcefield, cog, cofactors=None):
    return argparse.Namespace(
        log_level="info",
        input_pdb_file=input_name,
        FF=forcefield,
        cog=cog.split(),
        sphereradius=SPHERE_RADIUS,
        cysbond="auto",
        solvent_pack=3.0,
        skip_neutralization=False,
        neutralize_boundary_offset=0.0,
        salt_bridge_cutoff=SALT_BRIDGE_CUTOFF,
        skip_fragment_filter=True,
        cofactors=cofactors or [],
    )


def copy_pfkfb3_inputs(destination):
    # To re-parametrize the cofactors for pfkfb3, go to the makefile in perturbations/.
    # Here we just copy the existing files to the directory and reuse them for the benchmark.
    shutil.copy2(
        STARTFILES / "pfkfb3" / "protein" / "cofactors.pdb",
        destination / "cofactors.pdb",
    )
    for name in ("AMBER14sb_plus_cofactor.lib", "AMBER14sb_plus_cofactor.prm"):
        shutil.copy2(PERTURBATIONS / "pfkfb3" / name, destination / name)


def json_safe(value):
    if isinstance(value, np.ndarray):
        return value.tolist()
    if isinstance(value, np.generic):
        return value.item()
    raise TypeError(f"Cannot serialize {type(value).__name__}")


def effective_radius(qprep_out):
    match = EFFECTIVE_RADIUS_RE.search(Path(qprep_out).read_text())
    if not match:
        raise ValueError(f"Effective solvent radius not found in {qprep_out}")
    return float(match.group(1))

# %%
preparation_summary = {}

for target in TARGETS:
    print(f"\n=== {target} ===")
    protein_dir = STARTFILES / target / "protein"
    run_dir = protein_dir / QPREP_DIRNAME
    run_dir.mkdir(parents=True, exist_ok=True)
    shutil.copy2(protein_dir / "protein_reindexed_renamed.pdb", run_dir / "protein.pdb")

    forcefield = "AMBER14sb"
    cofactors = []
    if target == "pfkfb3":
        copy_pfkfb3_inputs(run_dir)
        forcefield = "AMBER14sb_plus_cofactor"
        cofactors = ["cofactors.pdb"]

    with working_directory(run_dir):
        neutralization = run_qprep_prot(
            make_qprep_args("protein.pdb", forcefield, LEGACY_COG[target], cofactors)
        )

    prepared_pdb = run_dir / "protein_processed.pdb"
    summary = {
        "target": target,
        "nominal_radius": SPHERE_RADIUS,
        "legacy_cog": [float(value) for value in LEGACY_COG[target].split()],
        "effective_solvent_radius": effective_radius(run_dir / "qprep.out"),
        "neutralization": neutralization,
        "forcefield": forcefield,
        "prepared_pdb": str(prepared_pdb.relative_to(STARTFILES)),
        "water_pdb": str((run_dir / "water.pdb").relative_to(STARTFILES)),
    }
    (run_dir / "preparation.json").write_text(json.dumps(summary, indent=2, default=json_safe) + "\n")
    preparation_summary[target] = summary
    print(
        f"neutralized={neutralization['residues_neutralized']}, "
        f"boundary salt-bridge partners={neutralization['salt_bridges_neutralized']}, "
        f"effective radius={summary['effective_solvent_radius']:.2f} Å"
    )

# %% [markdown]
# ## 3. Validate generated inputs
#
# `water.pdb` is a newly generated qprep solvent sphere; it does not preserve the input crystal waters. Keeping the legacy COG fixes the solvent-grid origin, while corrected protein atoms can legitimately change local water occupancy.

# %%
for target in TARGETS:
    run_dir = STARTFILES / target / "protein" / QPREP_DIRNAME
    protein = run_dir / "protein_processed.pdb"
    water = run_dir / "water.pdb"
    qprep_out = run_dir / "qprep.out"
    for required in (protein, water, qprep_out, run_dir / "dualtop.top"):
        if not required.is_file():
            raise FileNotFoundError(required)

    identities = set()
    for line in protein.read_text().splitlines():
        if not line.startswith(("ATOM  ", "HETATM")):
            continue
        identity = (line[21:27], line[17:21].strip(), line[12:16].strip())
        if identity in identities:
            raise ValueError(f"{target}: duplicate atom identity {identity}")
        identities.add(identity)

    expected_header = f"COG {LEGACY_COG[target]}"
    if expected_header not in water.open().readline():
        raise ValueError(f"{target}: water sphere does not use legacy COG")

print(f"Validated {len(TARGETS)} targets")

# %% [markdown]
# ## 4. Copy canonical inputs to `perturbations/`
#
# This cell overwrites the canonical parameter, protein, and water inputs for each target. Run it only after reviewing the preparation manifests and validation output. Submission/setup scripts are not modified.

# %%
COPY_TO_PERTURBATIONS = True

if not COPY_TO_PERTURBATIONS:
    print("Set COPY_TO_PERTURBATIONS = True after reviewing the generated inputs.")
else:
    for target in TARGETS:
        source_target = STARTFILES / target
        destination = PERTURBATIONS / target
        ligand_dir = source_target / "ligands"
        run_dir = source_target / "protein" / QPREP_DIRNAME

        for pattern in ("*.pdb", "*.lib", "*.prm"):
            for source in sorted(ligand_dir.glob(pattern)):
                shutil.copy2(source, destination / source.name)
        shutil.copy2(ligand_dir / "ligands.sdf", destination / "ligands.sdf")
        if (ligand_dir / "mapping.json").exists():
            shutil.copy2(ligand_dir / "mapping.json", destination / "mapping.json")
        shutil.copy2(run_dir / "protein_processed.pdb", destination / "protein.pdb")
        shutil.copy2(run_dir / "water.pdb", destination / "water.pdb")
        shutil.copy2(run_dir / "preparation.json", destination / "preparation.json")

        print(f"Updated {destination}")
