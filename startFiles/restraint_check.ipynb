# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re
import json
from pathlib import Path
from typing import Any, Dict, Tuple, Union, Literal

from IPython.display import clear_output, display
from ipywidgets import Layout, widgets
from openff.toolkit import Molecule
from QligFEP.chemIO import MoleculeIO
from QligFEP.CLI.utils import get_avail_restraint_methods
from QligFEP.logger import logger, setup_logger
from QligFEP.restraints.restraint_setter import RestraintSetter
from QligFEP.visualization import render_ligand_restraints
from rdkit import Chem


def apply_and_render_restraint(
    ligand1: Union[Molecule, Chem.Mol, str, Path],
    ligand2: Union[Molecule, Chem.Mol, str, Path],
    restraint_method: str = "hybridization_p",
    show_atom_idxs: bool = True,
    size: tuple[int, int] = (900, 500),
    sphere_palette: str = "hsv",
    sphere_radius: float = 0.6,
    sphere_alpha: float = 0.8,
) -> Tuple[dict[int, int], Any]:  # Return both dictionary and view
    """Modified version of apply_and_render_restraint that returns both the restraint dict
    and the rendered view.

    Returns:
        Tuple[dict[int, int], Any]: Tuple containing:
            - Dictionary of atom indexes containing the atoms to be restrained
            - The rendered view object
    """
    # Your existing code until render_ligand_restraints
    ligand1 = RestraintSetter.input_to_small_molecule_component(ligand1)
    ligand2 = RestraintSetter.input_to_small_molecule_component(ligand2)

    pattern = r"_(\d+\.?\d*)"  # check for the optional atom max distance
    match = re.search(pattern, restraint_method)
    if match:
        atom_max_distance = float(match.group(1))
        restraint_method = re.sub(pattern, "", restraint_method)
    else:
        atom_max_distance = 0.95

    if restraint_method not in get_avail_restraint_methods():
        raise ValueError(
            f"restraint_method should be one of {get_avail_restraint_methods()}, got {restraint_method}"
        )
    elif restraint_method == "overlap":
        raise ValueError("Overlap method is not supported by this method yet, use `kartograf` instead.")

    rsetter = RestraintSetter(ligand1, ligand2, kartograf_max_atom_distance=atom_max_distance)

    if restraint_method == "kartograf":
        restraint_dict = rsetter.set_restraints(
            kartograf_native=True,
        )
    else:
        atom_compare_method, permissiveness_lvl = restraint_method.split("_")
        if permissiveness_lvl == "p":
            params = {"strict_surround": False}
        elif permissiveness_lvl == "ls":
            params = {"strict_surround": True, "ignore_surround_atom_type": True}
        elif permissiveness_lvl == "strict":
            params = {"strict_surround": True, "ignore_surround_atom_type": False}
        restraint_dict = rsetter.set_restraints(atom_compare_method=atom_compare_method, **params)
        logger.debug(f"Restraints set using {restraint_method} method. Parameters: {params}")

    # Modify render_ligand_restraints to return the view
    view = render_ligand_restraints(
        ligand1,
        ligand2,
        restraint_dict,
        show_atom_idxs=show_atom_idxs,
        size=size,
        sphere_palette=sphere_palette,
        sphere_radius=sphere_radius,
        sphere_alpha=sphere_alpha,
        render=False,
    )

    n_restrained = len(restraint_dict.keys())
    natoms_lig1 = len(ligand1.to_rdkit().GetAtoms())
    natoms_lig2 = len(ligand2.to_rdkit().GetAtoms())
    similarity = n_restrained**2 / (natoms_lig1 * natoms_lig2)
    logger.info(f"FEP {ligand1.name} -> {ligand2.name} similarity = {similarity:.3f}")

    return restraint_dict, view


class ViewWrapper:
    def __init__(self, view):
        self.view = view

    def _repr_html_(self):
        return self.view._repr_html_()

    def __repr__(self):
        return ""  # Return empty string to suppress the repr output


class RestraintsViewer:
    def __init__(self, navigation_type: Literal["arrows", "dropdown"] = "arrows"):
        """Initialize the RestraintsViewer with a specific navigation type.

        Args:
            navigation_type: Type of navigation UI to use.
                "arrows" - Use previous/next buttons (original)
                "dropdown" - Use a dropdown menu for direct selection
        """
        self.navigation_type = navigation_type
        self.current_idx = 0
        self.views = []
        self.restraint_dicts = []
        self.descriptions = []
        self.molecule_names = []

        # Create output widget for the viewer
        self.output = widgets.Output()

        # Create molecule info display (used in both navigation types)
        self.molecule_info = widgets.HTML(value="", layout=Layout(width="100%"))

        # Initialize navigation widgets based on selected type
        if navigation_type == "arrows":
            self._init_arrows_navigation()
        else:  # dropdown
            self._init_dropdown_navigation()

    def _init_arrows_navigation(self):
        """Initialize arrow-based navigation (original implementation)."""
        # Create button widgets
        self.prev_button = widgets.Button(
            description="Previous",
            disabled=True,
            button_style="",
            tooltip="Go to previous pair",
            icon="chevron-left",
            layout=Layout(width="100px"),
        )

        self.next_button = widgets.Button(
            description="Next",
            disabled=True,
            button_style="",
            tooltip="Go to next pair",
            icon="chevron-right",
            layout=Layout(width="100px"),
        )

        # Create index label
        self.index_label = widgets.HTML(value="0/0", layout=Layout(width="100px"))

        # Set up callbacks
        self.prev_button.on_click(self._on_prev_clicked)
        self.next_button.on_click(self._on_next_clicked)

        # Create navigation box with centered elements
        self.nav_box = widgets.HBox(
            [self.prev_button, self.index_label, self.next_button],
            layout=Layout(
                display="flex",
                flex_flow="row",
                align_items="center",
                justify_content="center",
                width="100%",
            ),
        )

        # Create main widget with proper layout
        self.widget = widgets.VBox(
            [self.output, self.molecule_info, self.nav_box],
            layout=Layout(display="flex", flex_flow="column", align_items="center", width="100%"),
        )

    def _init_dropdown_navigation(self):
        """Initialize dropdown-based navigation."""
        # Create dropdown widget for molecule selection
        self.dropdown = widgets.Dropdown(
            options=[],
            description="Select Pair:",
            disabled=False,
            layout=Layout(width="400px"),
        )

        # Set up callbacks
        self.dropdown.observe(self._on_dropdown_change, names="value")

        # Create main widget with proper layout
        self.widget = widgets.VBox(
            [self.dropdown, self.output, self.molecule_info],
            layout=Layout(display="flex", flex_flow="column", align_items="center", width="100%"),
        )

    def add_view(
        self,
        restraint_dict: Dict,
        view: Any,
        description: str = "",
        molecule_names: tuple = None,
    ):
        """Add a new view to the viewer."""
        self.restraint_dicts.append(restraint_dict)
        self.views.append(ViewWrapper(view))  # Wrap the view
        self.descriptions.append(description)
        self.molecule_names.append(molecule_names)

        # Update navigation based on type
        if self.navigation_type == "arrows":
            self._update_buttons()
        else:  # dropdown
            self._update_dropdown()

        # If this is the first view, display it
        if len(self.views) == 1:
            self._display_current()

    def _update_buttons(self):
        """Update the state of arrow navigation buttons and labels."""
        if self.navigation_type != "arrows":
            return

        self.prev_button.disabled = self.current_idx <= 0
        self.next_button.disabled = self.current_idx >= len(self.views) - 1
        self.index_label.value = (
            f"<div style='text-align: center'>Pair {self.current_idx + 1} of {len(self.views)}</div>"
        )

    def _update_dropdown(self):
        """Update the dropdown menu options."""
        if self.navigation_type != "dropdown":
            return

        options = []
        for i, names in enumerate(self.molecule_names):
            if names:
                from_mol, to_mol = names
                label = f"{from_mol} → {to_mol}"
                options.append((label, i))  # (label, value) tuple

        self.dropdown.options = options

        # Set the current value if this is the first update
        if options and self.dropdown.value is None:
            self.dropdown.value = options[0][1]  # The value is the index

    def _display_current(self):
        """Display the current view and update info."""
        with self.output:
            clear_output(wait=True)
            display(self.views[self.current_idx])

        # Update molecule info
        if self.molecule_names[self.current_idx]:
            from_mol, to_mol = self.molecule_names[self.current_idx]
            self.molecule_info.value = (
                f'<div style="text-align: center">'
                f"Comparing pair {self.current_idx + 1} of {len(self.views)}: "
                f"{from_mol} → {to_mol}"
                f"</div>"
            )

    def _on_prev_clicked(self, b):
        """Handle previous button click."""
        if self.current_idx > 0:
            self.current_idx -= 1
            self._display_current()
            self._update_buttons()

    def _on_next_clicked(self, b):
        """Handle next button click."""
        if self.current_idx < len(self.views) - 1:
            self.current_idx += 1
            self._display_current()
            self._update_buttons()

    def _on_dropdown_change(self, change):
        """Handle dropdown selection change."""
        if change.new is not None:
            self.current_idx = change.new
            self._display_current()

    def display(self):
        """Display the widget"""
        display(self.widget)


# Example usage:
def process_multiple_restraints(
    ligand_pairs,
    molecule_names,
    method="hybridization_p",
    size=(900, 500),
    navigation_type="arrows",  # Added parameter with default to original behavior
):
    """
    Process multiple ligand pairs with different restraint methods.

    Args:
        ligand_pairs: List of ligand pairs to process
        molecule_names: List of molecule name pairs
        method: Restraint method to use
        size: Size tuple for visualization
        navigation_type: Type of navigation UI to use
            "arrows" - Use previous/next buttons (original)
            "dropdown" - Use a dropdown menu for direct selection
    """
    viewer = RestraintsViewer(navigation_type=navigation_type)

    for idx, ((lig1, lig2), (from_name, to_name)) in enumerate(zip(ligand_pairs, molecule_names)):
        restraint_dict, view = apply_and_render_restraint(lig1, lig2, restraint_method=method, size=size)
        description = f"Pair {idx + 1} - Method: {method}"
        viewer.add_view(restraint_dict, view, description, molecule_names=(from_name, to_name))

    viewer.display()
    return viewer

# %% [markdown]
# # JACS dataset

# %% [markdown]
# ## bace

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/bace/ligands.sdf")
network_dict = json.loads(Path("../perturbations/bace/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="hybridization_p", size=(1200, 500)
)

# %% [markdown]
# ## cdk2

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/cdk2/ligands.sdf")
network_dict = json.loads(Path("../perturbations/cdk2/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="hybridization_p", size=(1200, 500)
)

# %% [markdown]
# ## jnk1

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/jnk1/ligands.sdf")
network_dict = json.loads(Path("../perturbations/jnk1/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="hybridization_p", size=(1200, 500)
)

# %% [markdown]
# ## mcl1

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/mcl1/ligands.sdf")
network_dict = json.loads(Path("../perturbations/mcl1/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p", size=(1200, 500)
)

# %% [markdown]
# ## p38

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/p38/ligands.sdf")
network_dict = json.loads(Path("../perturbations/p38/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p", size=(1200, 500)
)

# %% [markdown]
# ## ptp1b

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/ptp1b/ligands.sdf")
network_dict = json.loads(Path("../perturbations/ptp1b/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p", size=(1200, 500)
)
# Out:
# VBox(children=(Output(), HTML(value='<div style="text-align: center">Comparing pair 1 of 1: 23477 → 23330</div…

# %% [markdown]
# ## thrombin

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/thrombin/ligands.sdf")
network_dict = json.loads(Path("../perturbations/thrombin/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="hybridization_p", size=(1200, 500)
)

# %% [markdown]
# ## tyk2

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/tyk2/ligands.sdf")
network_dict = json.loads(Path("../perturbations/tyk2/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="hybridization_p", size=(1200, 500)
)

# %% [markdown]
# # Merck dataset

# %% [markdown]
# ## cdk8

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/cdk8/ligands.sdf")
network_dict = json.loads(Path("../perturbations/cdk8/mapping.json").read_text())

edges = sorted([edge for edge in network_dict["edges"]], key=lambda x: x["from"])

for edge in edges:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs,
    molecule_name_pairs,
    method="hybridization_p",
    size=(1200, 500),
    navigation_type="dropdown",
)
# Out:
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 13 -> 42-flipped similarity = 0.141
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 15 -> 14 similarity = 0.134
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 16-flipped -> 15 similarity = 0.245
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 16-flipped -> 18-flipped similarity = 0.126
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 16-flipped -> 14 similarity = 0.152
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 16-flipped -> 17-flipped similarity = 0.126
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 18-flipped -> 17-flipped similarity = 0.315
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 18-flipped -> 44-flipped similarity = 0.234
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 18-flipped -> 45-flipped similarity = 0.220
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 19 -> 27 similarity = 0.222
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 19 -> 16-flipped similarity = 0.234
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 20 -> 32 similarity = 0.249
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 20 -> 19 similarity = 0.273
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 21 -> 26 similarity = 0.206
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 22 -> 21 similarity = 0.316
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 22 -> 26 similarity = 0.206
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 32 similarity = 0.305
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 25 similarity = 0.256
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 35 similarity = 0.235
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 39 similarity = 0.222
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 36 similarity = 0.222
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 19 similarity = 0.284
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 40 similarity = 0.218
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 34 similarity = 0.240
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 26 similarity = 0.220
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 24 -> 23 similarity = 0.220
# 2025-04-16 11:20:24 | INFO     | __main__:apply_and_render_restraint:88 - FEP 26 -> 32 similarity = 0.235
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 27 -> 25 similarity = 0.256
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 29 -> 32 similarity = 0.230
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 30 -> 31 similarity = 0.299
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 30 -> 38 similarity = 0.327
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 30 -> 13 similarity = 0.231
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 30 -> 24 similarity = 0.222
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 30 -> 42-flipped similarity = 0.125
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 32 -> 33 similarity = 0.280
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 32 -> 19 similarity = 0.305
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 32 -> 23 similarity = 0.235
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 32 -> 27 similarity = 0.238
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 32 -> 16-flipped similarity = 0.203
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 35 -> 36 similarity = 0.317
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 36 -> 34 similarity = 0.324
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 37 -> 38 similarity = 0.311
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 37 -> 31 similarity = 0.305
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 37 -> 24 similarity = 0.226
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 39 -> 41 similarity = 0.309
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 39 -> 40 similarity = 0.314
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 40 -> 41 similarity = 0.303
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 43 -> 42-flipped similarity = 0.123
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 43 -> 13 similarity = 0.128
# 2025-04-16 11:20:25 | INFO     | __main__:apply_and_render_restraint:88 - FEP 44-flipped -> 45-flipped similarity = 0.300
# VBox(children=(Dropdown(description='Select Pair:', layout=Layout(width='400px'), options=(('13 → 42-flipped',…

# %% [markdown]
# ## cmet

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/cmet/ligands.sdf")
network_dict = json.loads(Path("../perturbations/cmet/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_ls", size=(1200, 500)
)

# %% [markdown]
# ## eg5

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/eg5/ligands.sdf")
network_dict = json.loads(Path("../perturbations/eg5/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p", size=(1200, 500)
)

# %% [markdown]
# ## hif2a

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/hif2a/ligands.sdf")
network_dict = json.loads(Path("../perturbations/hif2a/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p", size=(1200, 500)
)

# %% [markdown]
# ## shp2

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/shp2/ligands.sdf")
network_dict = json.loads(Path("../perturbations/shp2/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p_1.2", size=(1200, 500)
)

# %% [markdown]
# ## syk

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/syk/ligands.sdf")
network_dict = json.loads(Path("../perturbations/syk/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p", size=(1200, 500)
)

# %% [markdown]
# ## pfkfb3

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/pfkfb3/ligands.sdf")
network_dict = json.loads(Path("../perturbations/pfkfb3/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="kartograf", size=(1200, 500)
)

# %% [markdown]
# ## tnks2

# %%
# Create pairs of molecule names along with the ligand pairs
molecule_name_pairs = []
ligand_pairs = []

chemio = MoleculeIO("../perturbations/tnks2/ligands.sdf")
network_dict = json.loads(Path("../perturbations/tnks2/mapping.json").read_text())

for edge in network_dict["edges"]:
    _from = edge["from"]
    _to = edge["to"]
    ligand1 = chemio.molecules[chemio.lig_names.index(_from)].to_rdkit()
    ligand2 = chemio.molecules[chemio.lig_names.index(_to)].to_rdkit()

    # Store both the ligand pairs and the name pairs
    ligand_pairs.append((ligand1, ligand2))
    molecule_name_pairs.append((_from, _to))

# Pass both ligand pairs and molecule names to the function
viewer = process_multiple_restraints(
    ligand_pairs, molecule_name_pairs, method="heavyatom_p", size=(1200, 500)
)

# %% [markdown]
# # Visualize systems

# %% [markdown]
# ## eg5

# %%
from pathlib import Path
from QligFEP.visualization import render_system
from QligFEP.chemIO import MoleculeIO

fileroot = Path("eg5/")
ligands = fileroot / "ligands/ligands.sdf"
protein = fileroot / "protein/protein.pdb"

chemio = MoleculeIO(ligands)

render_system(molecules=chemio.molecules, protein_path=protein)

# %% [markdown]
# ## bace

# %%
from pathlib import Path
from QligFEP.visualization import render_system
from QligFEP.chemIO import MoleculeIO

fileroot = Path("bace/")
ligands = fileroot / "ligands/ligands.sdf"
protein = fileroot / "protein/protein.pdb"

chemio = MoleculeIO(ligands)

render_system(molecules=chemio.molecules, protein_path=protein)

# %% [markdown]
# ## cdk2

# %%
from pathlib import Path
from QligFEP.visualization import render_system
from QligFEP.chemIO import MoleculeIO

fileroot = Path("cdk2/")
ligands = fileroot / "ligands/ligands.sdf"
protein = fileroot / "protein/protein.pdb"

chemio = MoleculeIO(ligands)

render_system(molecules=chemio.molecules, protein_path=protein)
